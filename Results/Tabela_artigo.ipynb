# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # TRAD

# %%
input_path ='/content/drive/MyDrive/Resultados/TRAD/tabelas/'
output_path ='/content/drive/MyDrive/Resultados/TRAD/tabelas/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                               1               5  \
# Dataframe
# CSTR_keyphrase23_GAT             0.5803 + 0.132   0.812 + 0.047
# CSTR_keyphrase23_GCN              0.595 + 0.214   0.795 + 0.049
# CSTR_keyphrase2_GAT               0.5358 + 0.12  0.8243 + 0.031
# CSTR_keyphrase2_GCN              0.5852 + 0.189  0.7964 + 0.052
# CSTR_keyphrase3_GAT              0.5431 + 0.112   0.828 + 0.046
# CSTR_keyphrase3_GCN              0.5729 + 0.135  0.8225 + 0.046
# Dmoz_Computers_keyphrase23_GAT   0.2604 + 0.031  0.4991 + 0.013
# Dmoz_Computers_keyphrase23_GCN   0.2034 + 0.044  0.4563 + 0.023
# Dmoz_Computers_keyphrase2_GAT    0.2617 + 0.035  0.4898 + 0.014
# Dmoz_Computers_keyphrase2_GCN    0.2122 + 0.046  0.4519 + 0.019
# Dmoz_Computers_keyphrase3_GAT    0.2752 + 0.034   0.502 + 0.011
# Dmoz_Computers_keyphrase3_GCN    0.2231 + 0.039  0.4642 + 0.018
# Dmoz_Health_keyphrase23_GAT      0.4599 + 0.067  0.7133 + 0.016
# ...

# %%
df_f1[36:72]
# Out:
#                                               1               5  \
# Dataframe
# NSF_keyphrase23_GAT              0.5372 + 0.055   0.7409 + 0.02
# NSF_keyphrase23_GCN              0.4999 + 0.056  0.6955 + 0.028
# NSF_keyphrase2_GAT                0.532 + 0.051  0.7367 + 0.017
# NSF_keyphrase2_GCN               0.4804 + 0.043  0.6925 + 0.041
# NSF_keyphrase3_GAT               0.5573 + 0.047  0.7434 + 0.016
# NSF_keyphrase3_GCN               0.4929 + 0.068  0.6969 + 0.033
# SyskillWebert_keyphrase23_GAT     0.6357 + 0.08  0.8469 + 0.045
# SyskillWebert_keyphrase23_GCN    0.5628 + 0.122  0.7528 + 0.032
# SyskillWebert_keyphrase2_GAT      0.6547 + 0.08  0.8557 + 0.033
# SyskillWebert_keyphrase2_GCN     0.5795 + 0.134  0.7352 + 0.057
# SyskillWebert_keyphrase3_GAT     0.5815 + 0.085  0.8433 + 0.044
# SyskillWebert_keyphrase3_GCN     0.5535 + 0.099   0.7421 + 0.06
# classic4_keyphrase23_GAT         0.7612 + 0.085  0.8866 + 0.045
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
lista = [df_f1]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', '1',	'5',	'10',	'20',	'30',	'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

lista = [df_f1_mean]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## Tabela compara indutivo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean
# Out:
#                                      1         5        10        20        30
# Dataframe
# CSTR_keyphrase23_GAT          0.580277  0.811999  0.836131  0.811409       NaN
# CSTR_keyphrase23_GCN          0.594979  0.794995  0.819313  0.801470       NaN
# CSTR_keyphrase2_GAT           0.535783  0.824261  0.847399  0.816010       NaN
# CSTR_keyphrase2_GCN           0.585179  0.796397  0.806770  0.803067       NaN
# CSTR_keyphrase3_GAT           0.543135  0.828019  0.833142  0.811387       NaN
# ...                                ...       ...       ...       ...       ...
# webkb_parsed_keyphrase23_GCN  0.115618  0.253510  0.269867  0.222162  0.318071
# webkb_parsed_keyphrase2_GAT   0.169443  0.314226  0.374042  0.413629  0.440611
# webkb_parsed_keyphrase2_GCN   0.134415  0.262501  0.242717  0.273766  0.221325
# webkb_parsed_keyphrase3_GAT   0.159577  0.328723  0.372211  0.416038  0.446037
# webkb_parsed_keyphrase3_GCN   0.148489  0.251177  0.269110  0.293658  0.236768
#
# ...

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', '1',	'5',	'10',	'20',	'30']]
    return df

df_f1 =  ajust_table(df_f1_mean)

# %%
df_GCN = df_f1[df_f1['GNN Model'] == 'GCN']
df_GAT = df_f1[df_f1['GNN Model'] == 'GAT']
df_GCN = df_GCN.fillna(0)
df_GAT = df_GAT.fillna(0)

# %%
lista_maximos = []
for i in range(12):
    l=i*3
    df = df_GCN[l:l+3]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_GCN.loc[i,j])

def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_GCN.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %%
lista_valores_maximos
# Out:
# ['CSTR',
#  '[3]',
#  'GCN',
#  0.5949791329904783,
#  0.8225413455071948,
#  0.8193134455260941,
#  0.8030669649880451,
#  0.0,
#  'Dmoz_Computers',
#  '[3]',
#  'GCN',
#  0.2231148529983016,
#  0.4641986571112351,
#  0.5345304562310937,
#  0.5779254061482078,
#  0.6005145846352323,
#  'Dmoz_Health',
#  '[3]',
#  'GCN',
#  0.3853954578401636,
#  0.6532217360412405,
#  0.7243814608056964,
#  0.7697322763043416,
#  0.7948878257253803,
#  'Dmoz_Science',
#  '[3]',
#  'GCN',
#  0.3161522664285782,
#  0.5481161653302278,
#  0.6325822092449659,
#  0.6882605944786794,
#  0.702199446043268,
#  'Dmoz_Sports',
#  '[3]',
#  'GCN',
#  0.338423497231586,
#  0.6607370712631357,
#  0.7249637114183525,
#  0.7638880231840902,
#  0.7838372620833437,
#  'Industry_Sector',
#  '[3]',
#  'GCN',
#  0.1069857826629934,
#  0.226117607724503,
#  0.2995642342420773,
#  0.3103584737428467,
#  0.3452161432005721,
#  'NSF',
#  '[3]',
#  'GCN',
#  0.4998622968602993,
#  0.696937968012359,
#  0.7557797371508888,
# ...

# %%
lista_valores_maximos = ['CSTR',
 '[3]',
 'GCN',
 0.5949791329904783,
 0.8225413455071948,
 0.8193134455260941,
 0.8030669649880451,
 0.0,
 'Dmoz_Computers',
 '[3]',
 'GCN',
 0.2231148529983016,
 0.4641986571112351,
 0.5345304562310937,
 0.5779254061482078,
 0.6005145846352323,
 'Dmoz_Health',
 '[3]',
 'GCN',
 0.3853954578401636,
 0.6532217360412405,
 0.7243814608056964,
 0.7697322763043416,
 0.7948878257253803,
 'Dmoz_Science',
 '[3]',
 'GCN',
 0.3161522664285782,
 0.5481161653302278,
 0.6325822092449659,
 0.6882605944786794,
 0.702199446043268,
 'Dmoz_Sports',
 '[3]',
 'GCN',
 0.338423497231586,
 0.6607370712631357,
 0.7249637114183525,
 0.7638880231840902,
 0.7838372620833437,
 'Industry_Sector',
 '[3]',
 'GCN',
 0.1069857826629934,
 0.226117607724503,
 0.2995642342420773,
 0.3103584737428467,
 0.3452161432005721,
 'NSF',
 '[3]',
 'GCN',
 0.4998622968602993,
 0.696937968012359,
 0.7557797371508888,
 0.7627762884205121,
 0.779423856236504,
 'SyskillWebert',
 '[3]',
 'GCN',
 0.5795019225488239,
 0.7527734756588618,
 0.8391088084497852,
 0.8634578023194657,
 0.8637150883006528,
 'classic4',
 '[3]',
 'GCN',
 0.7268744288145261,
 0.8421582981265118,
 0.9117994507962066,
 0.9209392368283325,
 0.9284687659663704,
 're8',
 '[3]',
 'GCN',
 0.4750046980840081,
 0.6914847952367748,
 0.7498539480568508,
 0.7630449740321237,
 0.7486887583937658,
 'review_polarity',
 '[3]',
 'GCN',
 0.4436603499027821,
 0.4392916000819771,
 0.4730785330709103,
 0.4728107739051743,
 0.4507356476169541,
 'webkb_parsed',
 '[3]',
 'GCN',
 0.1484893834241039,
 0.2625012513053825,
 0.2698670659020096,
 0.2936582075639856,
 0.3180711800552759]

# %%
max_dit = {}
for i in range(12):
    j = i*8
    max_dit[lista_valores_maximos[j]] = round(max(lista_valores_maximos[j+3:j+8]),3)

# %%
max_dit
# Out:
# {'CSTR': 0.823,
#  'Dmoz_Computers': 0.601,
#  'Dmoz_Health': 0.795,
#  'Dmoz_Science': 0.702,
#  'Dmoz_Sports': 0.784,
#  'Industry_Sector': 0.345,
#  'NSF': 0.779,
#  'SyskillWebert': 0.864,
#  'classic4': 0.928,
#  're8': 0.763,
#  'review_polarity': 0.473,
#  'webkb_parsed': 0.318}

# %%
max_dit.values()
# Out:
# dict_values([0.823, 0.601, 0.795, 0.702, 0.784, 0.345, 0.779, 0.864, 0.928, 0.763, 0.473, 0.318])

# %%
lista_maximos = []
for i in range(12):
    l=i*3
    df = df_GAT[l:l+3]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_GAT.loc[i,j])

def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_GAT.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %%
lista_valores_maximos
# Out:
# ['CSTR',
#  '[3]',
#  'GAT',
#  0.5802770277710348,
#  0.828019026787451,
#  0.8473989889274263,
#  0.8160101064020123,
#  0.0,
#  'Dmoz_Computers',
#  '[3]',
#  'GAT',
#  0.2751864057017711,
#  0.501999082537366,
#  0.5613986495477483,
#  0.5995617123431558,
#  0.6192600708739205,
#  'Dmoz_Health',
#  '[3]',
#  'GAT',
#  0.4741111767054386,
#  0.714111275756047,
#  0.7738826629825637,
#  0.7995828422501179,
#  0.8114460872525877,
#  'Dmoz_Science',
#  '[3]',
#  'GAT',
#  0.3596321743139903,
#  0.605318062765633,
#  0.6564456938810371,
#  0.7015968040679734,
#  0.7211150046100918,
#  'Dmoz_Sports',
#  '[3]',
#  'GAT',
#  0.4568938531909007,
#  0.738543328125926,
#  0.7779146481754691,
#  0.815765249314604,
#  0.8274951407738758,
#  'Industry_Sector',
#  '[3]',
#  'GAT',
#  0.1344277560105301,
#  0.3101637547021328,
#  0.3901381167810386,
#  0.4535984743769264,
#  0.482702559971348,
#  'NSF',
#  '[3]',
#  'GAT',
#  0.5572891869665875,
#  0.7434460272280299,
#  0.7829552375275116,
# ...

# %%
lista_valores_maximos = ['CSTR',
 '[3]',
 'GAT',
 0.5802770277710348,
 0.828019026787451,
 0.8473989889274263,
 0.8160101064020123,
 0.0,
 'Dmoz_Computers',
 '[3]',
 'GAT',
 0.2751864057017711,
 0.501999082537366,
 0.5613986495477483,
 0.5995617123431558,
 0.6192600708739205,
 'Dmoz_Health',
 '[3]',
 'GAT',
 0.4741111767054386,
 0.714111275756047,
 0.7738826629825637,
 0.7995828422501179,
 0.8114460872525877,
 'Dmoz_Science',
 '[3]',
 'GAT',
 0.3596321743139903,
 0.605318062765633,
 0.6564456938810371,
 0.7015968040679734,
 0.7211150046100918,
 'Dmoz_Sports',
 '[3]',
 'GAT',
 0.4568938531909007,
 0.738543328125926,
 0.7779146481754691,
 0.815765249314604,
 0.8274951407738758,
 'Industry_Sector',
 '[3]',
 'GAT',
 0.1344277560105301,
 0.3101637547021328,
 0.3901381167810386,
 0.4535984743769264,
 0.482702559971348,
 'NSF',
 '[3]',
 'GAT',
 0.5572891869665875,
 0.7434460272280299,
 0.7829552375275116,
 0.7875770283440013,
 0.807184176521698,
 'SyskillWebert',
 '[3]',
 'GAT',
 0.6546701450594952,
 0.8556536964989409,
 0.8894456797306647,
 0.9125704173898788,
 0.9044163023525632,
 'classic4',
 '[3]',
 'GAT',
 0.7955757534972604,
 0.8959965088155272,
 0.9263075537653782,
 0.940460621109876,
 0.9418738396708898,
 're8',
 '[3]',
 'GAT',
 0.5357744790828132,
 0.7561456260817846,
 0.8112483190195661,
 0.830383009425797,
 0.8208411468525834,
 'review_polarity',
 '[3]',
 'GAT',
 0.4782514618073672,
 0.4815873073745721,
 0.5226014662386771,
 0.5503149862284402,
 0.5689178504664418,
 'webkb_parsed',
 '[3]',
 'GAT',
 0.1694428394219767,
 0.3287225735599985,
 0.3740422647773005,
 0.4160384452609517,
 0.4460373449478097]

# %%
max_dit = {}
for i in range(12):
    j = i*8
    max_dit[lista_valores_maximos[j]] = round(max(lista_valores_maximos[j+3:j+8]),3)

# %%
max_dit
# Out:
# {'CSTR': 0.847,
#  'Dmoz_Computers': 0.619,
#  'Dmoz_Health': 0.811,
#  'Dmoz_Science': 0.721,
#  'Dmoz_Sports': 0.827,
#  'Industry_Sector': 0.483,
#  'NSF': 0.807,
#  'SyskillWebert': 0.913,
#  'classic4': 0.942,
#  're8': 0.83,
#  'review_polarity': 0.569,
#  'webkb_parsed': 0.446}

# %%
max_dit.values()
# Out:
# dict_values([0.847, 0.619, 0.811, 0.721, 0.827, 0.483, 0.807, 0.913, 0.942, 0.83, 0.569, 0.446])

# %% [markdown]
# # TRAD 80

# %%
input_path ='/content/drive/MyDrive/Resultados/TRAD/tabelas_80/'
output_path ='/content/drive/MyDrive/Resultados/TRAD/tabelas_80/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                               1               5  \
# Dataframe
# CSTR_keyphrase23_GAT             0.5803 + 0.132   0.812 + 0.047
# CSTR_keyphrase23_GCN              0.595 + 0.214   0.795 + 0.049
# CSTR_keyphrase2_GAT               0.5358 + 0.12  0.8243 + 0.031
# CSTR_keyphrase2_GCN              0.5852 + 0.189  0.7964 + 0.052
# CSTR_keyphrase3_GAT              0.5431 + 0.112   0.828 + 0.046
# CSTR_keyphrase3_GCN              0.5729 + 0.135  0.8225 + 0.046
# Dmoz_Computers_keyphrase23_GAT   0.2604 + 0.031  0.4991 + 0.013
# Dmoz_Computers_keyphrase23_GCN   0.2034 + 0.044  0.4563 + 0.023
# Dmoz_Computers_keyphrase2_GAT    0.2617 + 0.035  0.4898 + 0.014
# Dmoz_Computers_keyphrase2_GCN    0.2122 + 0.046  0.4519 + 0.019
# Dmoz_Computers_keyphrase3_GAT    0.2752 + 0.034   0.502 + 0.011
# Dmoz_Computers_keyphrase3_GCN    0.2231 + 0.039  0.4642 + 0.018
# Dmoz_Health_keyphrase23_GAT      0.4599 + 0.067  0.7133 + 0.016
# ...

# %%
df_f1[36:72]
# Out:
#                                               1               5  \
# Dataframe
# NSF_keyphrase23_GAT              0.5372 + 0.055   0.7409 + 0.02
# NSF_keyphrase23_GCN              0.4999 + 0.056  0.6955 + 0.028
# NSF_keyphrase2_GAT                0.532 + 0.051  0.7367 + 0.017
# NSF_keyphrase2_GCN               0.4804 + 0.043  0.6925 + 0.041
# NSF_keyphrase3_GAT               0.5573 + 0.047  0.7434 + 0.016
# NSF_keyphrase3_GCN               0.4929 + 0.068  0.6969 + 0.033
# SyskillWebert_keyphrase23_GAT     0.6357 + 0.08  0.8469 + 0.045
# SyskillWebert_keyphrase23_GCN    0.5628 + 0.122  0.7528 + 0.032
# SyskillWebert_keyphrase2_GAT      0.6547 + 0.08  0.8557 + 0.033
# SyskillWebert_keyphrase2_GCN     0.5795 + 0.134  0.7352 + 0.057
# SyskillWebert_keyphrase3_GAT     0.5815 + 0.085  0.8433 + 0.044
# SyskillWebert_keyphrase3_GCN     0.5535 + 0.099   0.7421 + 0.06
# classic4_keyphrase23_GAT         0.7612 + 0.085  0.8866 + 0.045
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)
df_f1["80%"]  = round(df_f1_mean["80%"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["80%"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
lista = [df_f1]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', '1',	'5',	'10',	'20',	'30','80%',	'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

lista = [df_f1_mean]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # TRAD_PERCENT - 80 60 40 20

# %%
input_path ='/content/drive/MyDrive/Resultados/TRAD_PERCENT/tabelas/'
output_path ='/content/drive/MyDrive/Resultados/TRAD_PERCENT/tabelas/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

df_acc_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_pre_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_rec_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_f1_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_sup_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_time_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)

df_acc_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_pre_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_rec_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_f1_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_sup_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)
df_time_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
# df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
# df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
# df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
# df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
# df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["20%"]  = round(df_acc_mean["20%"], 4).astype(str)  + ' + ' + round(df_acc_std["20%"], 3).astype(str)
df_acc["40%"]  = round(df_acc_mean["40%"], 4).astype(str)  + ' + ' + round(df_acc_std["40%"], 3).astype(str)
df_acc["60%"]  = round(df_acc_mean["60%"], 4).astype(str)  + ' + ' + round(df_acc_std["60%"], 3).astype(str)
df_acc["80%"]  = round(df_acc_mean["80%"], 4).astype(str)  + ' + ' + round(df_acc_std["80%"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
# df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
# df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
# df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
# df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
# df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["20%"]  = round(df_pre_mean["20%"], 4).astype(str)  + ' + ' + round(df_pre_std["20%"], 3).astype(str)
df_pre["40%"]  = round(df_pre_mean["40%"], 4).astype(str)  + ' + ' + round(df_pre_std["40%"], 3).astype(str)
df_pre["60%"]  = round(df_pre_mean["60%"], 4).astype(str)  + ' + ' + round(df_pre_std["60%"], 3).astype(str)
df_pre["80%"]  = round(df_pre_mean["80%"], 4).astype(str)  + ' + ' + round(df_pre_std["80%"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
# df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
# df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
# df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
# df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
# df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["20%"]  = round(df_rec_mean["20%"], 4).astype(str)  + ' + ' + round(df_rec_std["20%"], 3).astype(str)
df_rec["40%"]  = round(df_rec_mean["40%"], 4).astype(str)  + ' + ' + round(df_rec_std["40%"], 3).astype(str)
df_rec["60%"]  = round(df_rec_mean["60%"], 4).astype(str)  + ' + ' + round(df_rec_std["60%"], 3).astype(str)
df_rec["80%"]  = round(df_rec_mean["80%"], 4).astype(str)  + ' + ' + round(df_rec_std["80%"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
# df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
# df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
# df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
# df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
# df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["20%"]  = round(df_f1_mean["20%"], 4).astype(str)  + ' + ' + round(df_f1_std["20%"], 3).astype(str)
df_f1["40%"]  = round(df_f1_mean["40%"], 4).astype(str)  + ' + ' + round(df_f1_std["40%"], 3).astype(str)
df_f1["60%"]  = round(df_f1_mean["60%"], 4).astype(str)  + ' + ' + round(df_f1_std["60%"], 3).astype(str)
df_f1["80%"]  = round(df_f1_mean["80%"], 4).astype(str)  + ' + ' + round(df_f1_std["80%"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
# df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
# df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
# df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
# df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
# df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["20%"]  = round(df_sup_mean["20%"], 4).astype(str)  + ' + ' + round(df_sup_std["20%"], 3).astype(str)
df_sup["40%"]  = round(df_sup_mean["40%"], 4).astype(str)  + ' + ' + round(df_sup_std["40%"], 3).astype(str)
df_sup["60%"]  = round(df_sup_mean["60%"], 4).astype(str)  + ' + ' + round(df_sup_std["60%"], 3).astype(str)
df_sup["80%"]  = round(df_sup_mean["80%"], 4).astype(str)  + ' + ' + round(df_sup_std["80%"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
# df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
# df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
# df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
# df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
# df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
# lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

# for i in lista:
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                             20%             40%  \
# Dataframe
# CSTR_keyphrase23_GAT             0.8818 + 0.016   0.882 + 0.006
# CSTR_keyphrase23_GCN             0.8525 + 0.027  0.8672 + 0.016
# CSTR_keyphrase2_GAT               0.876 + 0.013  0.8766 + 0.011
# CSTR_keyphrase2_GCN              0.8328 + 0.033  0.8596 + 0.029
# CSTR_keyphrase3_GAT                0.862 + 0.03  0.8788 + 0.007
# CSTR_keyphrase3_GCN               0.869 + 0.025     0.87 + 0.01
# Dmoz_Computers_keyphrase23_GAT   0.6627 + 0.004  0.6815 + 0.004
# Dmoz_Computers_keyphrase23_GCN   0.6398 + 0.005  0.6664 + 0.005
# Dmoz_Computers_keyphrase2_GAT    0.6621 + 0.003  0.6773 + 0.004
# Dmoz_Computers_keyphrase2_GCN    0.6266 + 0.006  0.6563 + 0.007
# Dmoz_Computers_keyphrase3_GAT    0.6644 + 0.002  0.6828 + 0.002
# Dmoz_Computers_keyphrase3_GCN    0.6485 + 0.004  0.6733 + 0.006
# Dmoz_Health_keyphrase23_GAT      0.8505 + 0.003  0.8606 + 0.003
# ...

# %%
df_f1[36:72]
# Out:
#                                             20%             40%  \
# Dataframe
# NSF_keyphrase23_GAT              0.8509 + 0.002   0.859 + 0.002
# NSF_keyphrase23_GCN              0.8325 + 0.002  0.8466 + 0.001
# NSF_keyphrase2_GAT               0.8473 + 0.002  0.8527 + 0.003
# NSF_keyphrase2_GCN               0.8223 + 0.003  0.8332 + 0.004
# NSF_keyphrase3_GAT               0.8497 + 0.002  0.8598 + 0.002
# NSF_keyphrase3_GCN               0.8371 + 0.003  0.8491 + 0.003
# SyskillWebert_keyphrase23_GAT    0.8849 + 0.014  0.9071 + 0.012
# SyskillWebert_keyphrase23_GCN    0.8456 + 0.013   0.8707 + 0.02
# SyskillWebert_keyphrase2_GAT     0.9048 + 0.011  0.9355 + 0.011
# SyskillWebert_keyphrase2_GCN     0.8468 + 0.034  0.8539 + 0.045
# SyskillWebert_keyphrase3_GAT     0.8974 + 0.012  0.9134 + 0.007
# SyskillWebert_keyphrase3_GCN      0.832 + 0.021  0.8465 + 0.038
# classic4_keyphrase23_GAT         0.9614 + 0.002  0.9605 + 0.001
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)

df_f1_std.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
# df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
# df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
# df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
# df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
# df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)

df_f1["20%"]  = round(df_f1_mean["20%"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["20%"], 3).astype(str)
df_f1["40%"]  = round(df_f1_mean["40%"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["40%"], 3).astype(str)
df_f1["60%"]  = round(df_f1_mean["60%"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["60%"], 3).astype(str)
df_f1["80%"]  = round(df_f1_mean["80%"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["80%"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
# lista = [df_f1]

# for i in lista:
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
#     i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    #df = df[['Dataset',	'Keyphrases',	'GNN Model', '1',	'5', '10',	'20',	'30', '20%', '40%', '60%', '80%', 'media']]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', '20%', '40%', '60%', '80%', 'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)

lista = [df_f1_mean]

# for i in lista:
    # i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    # i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    # i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    # i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    # i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    # i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    # i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    # i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    # i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    # i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    # i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    # i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    # i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    # i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    # i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    # i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    # i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    # i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    # i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    # i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    # i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    # i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    # i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    # i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    # i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    # i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    # i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    # i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    # i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    # i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## Tabela compara indutivo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean.drop(['1',	'5',	'10',	'20',	'30'], axis=1,inplace=True)

df_f1_mean

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    # df = df[['Dataset',	'Keyphrases',	'GNN Model', '1',	'5',	'10',	'20',	'30', '20%', '40%', '60%', '80%']]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', '20%', '40%', '60%', '80%']]
    return df

df_f1 =  ajust_table(df_f1_mean)

# %%
df_GCN = df_f1[df_f1['GNN Model'] == 'GCN']
df_GAT = df_f1[df_f1['GNN Model'] == 'GAT']
df_GCN = df_GCN.fillna(0)
df_GAT = df_GAT.fillna(0)

# %%
lista_maximos = []
for i in range(12):
    l=i*3
    df = df_GCN[l:l+3]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_GCN.loc[i,j])

def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_GCN.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %%
lista_valores_maximos
# Out:
# ['CSTR',
#  '[3]',
#  'GCN',
#  0.8690091355672978,
#  0.8700003676363555,
#  0.8874383766100961,
#  0.8636781364424297,
#  'Dmoz_Computers',
#  '[3]',
#  'GCN',
#  0.6485089932628852,
#  0.6732627253433556,
#  0.6939214854208718,
#  0.7163616506249897,
#  'Dmoz_Health',
#  '[3]',
#  'GCN',
#  0.8338199981659316,
#  0.839077518423491,
#  0.8374120892471717,
#  0.8384331052966681,
#  'Dmoz_Science',
#  '[3]',
#  'GCN',
#  0.7604077603762113,
#  0.7769692180396419,
#  0.7849952102446398,
#  0.7979153803134762,
#  'Dmoz_Sports',
#  '[3]',
#  'GCN',
#  0.8295007377695833,
#  0.8356297268150256,
#  0.8370710737471997,
#  0.8374872830203628,
#  'Industry_Sector',
#  '[3]',
#  'GCN',
#  0.3969947934652864,
#  0.3933445485938338,
#  0.3468633607052077,
#  0.3893638923584241,
#  'NSF',
#  '[3]',
#  'GCN',
#  0.8370812163801526,
#  0.8491042482494011,
#  0.8548722137685327,
#  0.8534521548187595,
#  'SyskillWebert',
#  '[3]',
#  'GCN',
#  0.846800873716097,
#  0.8707430304468314,
# ...

# %%
max_dit = {}
for i in range(12):
    j = i*7
    max_dit[lista_valores_maximos[j]] = round(max(lista_valores_maximos[j+3:j+7]),3)

# %%
max_dit
# Out:
# {'CSTR': 0.887,
#  'Dmoz_Computers': 0.716,
#  'Dmoz_Health': 0.839,
#  'Dmoz_Science': 0.798,
#  'Dmoz_Sports': 0.837,
#  'Industry_Sector': 0.397,
#  'NSF': 0.855,
#  'SyskillWebert': 0.924,
#  'classic4': 0.962,
#  're8': 0.903,
#  'review_polarity': 0.479,
#  'webkb_parsed': 0.249}

# %%
max_dit.values()
# Out:
# dict_values([0.887, 0.716, 0.839, 0.798, 0.837, 0.397, 0.855, 0.924, 0.962, 0.903, 0.479, 0.249])

# %%
lista_maximos = []
for i in range(12):
    l=i*3
    df = df_GAT[l:l+3]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_GAT.loc[i,j])

def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_GAT.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %%
lista_valores_maximos
# Out:
# ['CSTR',
#  '[3]',
#  'GAT',
#  0.8817662931261643,
#  0.8820381478676754,
#  0.8916831451736073,
#  0.8694599223859644,
#  'Dmoz_Computers',
#  '[3]',
#  'GAT',
#  0.6644199010967597,
#  0.682765931048696,
#  0.7029070983862585,
#  0.7247357238253441,
#  'Dmoz_Health',
#  '[3]',
#  'GAT',
#  0.8523232616616575,
#  0.8630740808123345,
#  0.8658812702071368,
#  0.861273915664035,
#  'Dmoz_Science',
#  '[3]',
#  'GAT',
#  0.7764157601811821,
#  0.7975949094302148,
#  0.8026939947255807,
#  0.8205172826499716,
#  'Dmoz_Sports',
#  '[3]',
#  'GAT',
#  0.865820532787853,
#  0.8746470539143321,
#  0.8798122198802343,
#  0.8835971466210026,
#  'Industry_Sector',
#  '[3]',
#  'GAT',
#  0.6433455377685633,
#  0.7029257060206572,
#  0.7500048336210635,
#  0.7788936999581897,
#  'NSF',
#  '[3]',
#  'GAT',
#  0.8508768223821731,
#  0.8598469960399191,
#  0.860058442106809,
#  0.8616769253318127,
#  'SyskillWebert',
#  '[3]',
#  'GAT',
#  0.9047612737263906,
#  0.9354578278495664,
# ...

# %%
max_dit = {}
for i in range(12):
    j = i*7
    max_dit[lista_valores_maximos[j]] = round(max(lista_valores_maximos[j+3:j+7]),3)

# %%
max_dit
# Out:
# {'CSTR': 0.892,
#  'Dmoz_Computers': 0.725,
#  'Dmoz_Health': 0.866,
#  'Dmoz_Science': 0.821,
#  'Dmoz_Sports': 0.884,
#  'Industry_Sector': 0.779,
#  'NSF': 0.862,
#  'SyskillWebert': 0.948,
#  'classic4': 0.966,
#  're8': 0.887,
#  'review_polarity': 0.581,
#  'webkb_parsed': 0.61}

# %%
max_dit.values()
# Out:
# dict_values([0.892, 0.725, 0.866, 0.821, 0.884, 0.779, 0.862, 0.948, 0.966, 0.887, 0.581, 0.61])

# %% [markdown]
# # COARSENING

# %%
input_path ='/content/drive/MyDrive/Resultados/COARSENING/tabelas/'
output_path ='/content/drive/MyDrive/Resultados/COARSENING/tabelas/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                               1               5  \
# Dataframe
# CSTR_keyphrase23_GAT              0.4493 + 0.11  0.6589 + 0.112
# CSTR_keyphrase23_GCN             0.4511 + 0.153  0.6657 + 0.107
# CSTR_keyphrase2_GAT              0.4137 + 0.099  0.7058 + 0.062
# CSTR_keyphrase2_GCN                0.4208 + 0.1  0.6463 + 0.058
# CSTR_keyphrase3_GAT              0.4894 + 0.114  0.6722 + 0.083
# CSTR_keyphrase3_GCN              0.4168 + 0.151  0.6341 + 0.101
# Dmoz_Computers_keyphrase23_GAT   0.2341 + 0.029  0.4633 + 0.009
# Dmoz_Computers_keyphrase23_GCN   0.1974 + 0.031    0.43 + 0.026
# Dmoz_Computers_keyphrase2_GAT    0.2218 + 0.025   0.4368 + 0.01
# Dmoz_Computers_keyphrase2_GCN    0.1792 + 0.024  0.4031 + 0.013
# Dmoz_Computers_keyphrase3_GAT    0.2447 + 0.035   0.4619 + 0.01
# Dmoz_Computers_keyphrase3_GCN    0.2005 + 0.037  0.4427 + 0.015
# Dmoz_Health_keyphrase23_GAT      0.4039 + 0.048   0.6438 + 0.02
# ...

# %%
df_f1[36:72]
# Out:
#                                               1               5  \
# Dataframe
# NSF_keyphrase23_GAT              0.5356 + 0.047  0.7289 + 0.018
# NSF_keyphrase23_GCN              0.5164 + 0.027  0.6977 + 0.029
# NSF_keyphrase2_GAT                0.493 + 0.056  0.6909 + 0.016
# NSF_keyphrase2_GCN               0.4562 + 0.047   0.657 + 0.026
# NSF_keyphrase3_GAT               0.5365 + 0.067  0.7207 + 0.018
# NSF_keyphrase3_GCN               0.4796 + 0.066  0.7015 + 0.014
# SyskillWebert_keyphrase23_GAT    0.4249 + 0.042  0.4921 + 0.027
# SyskillWebert_keyphrase23_GCN     0.3838 + 0.06   0.4835 + 0.05
# SyskillWebert_keyphrase2_GAT     0.4024 + 0.057   0.507 + 0.027
# SyskillWebert_keyphrase2_GCN      0.372 + 0.046  0.4565 + 0.023
# SyskillWebert_keyphrase3_GAT     0.3953 + 0.052  0.4952 + 0.046
# SyskillWebert_keyphrase3_GCN     0.4009 + 0.058   0.464 + 0.029
# classic4_keyphrase23_GAT          0.742 + 0.105  0.8126 + 0.075
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
lista = [df_f1]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', '1',	'5',	'10',	'20',	'30',	'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

lista = [df_f1_mean]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # LLM 10

# %%
input_path ='/content/drive/MyDrive/Resultados/LLM/10/tabelas/'
output_path ='/content/drive/MyDrive/Resultados/LLM/10/tabelas/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
df_acc["LLM_only"]   = round(df_acc_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_acc_std["LLM_only"], 3).astype(str)
df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
df_pre["LLM_only"]   = round(df_pre_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_pre_std["LLM_only"], 3).astype(str)
df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
df_rec["LLM_only"]   = round(df_rec_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_rec_std["LLM_only"], 3).astype(str)
df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
df_f1["LLM_only"]   = round(df_f1_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_f1_std["LLM_only"], 3).astype(str)
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
df_sup["LLM_only"]   = round(df_sup_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_sup_std["LLM_only"], 3).astype(str)
df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
df_time["LLM_only"]   = round(df_time_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_time_std["LLM_only"], 3).astype(str)
df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                        LLM_only               1  \
# Dataframe
# CSTR_keyphrase23_GAT              0.7575 + 0.07  0.7585 + 0.091
# CSTR_keyphrase23_GCN             0.7428 + 0.062  0.7485 + 0.068
# CSTR_keyphrase2_GAT              0.7625 + 0.052  0.7711 + 0.054
# CSTR_keyphrase2_GCN              0.7429 + 0.067  0.7446 + 0.066
# CSTR_keyphrase3_GAT              0.7545 + 0.063  0.7675 + 0.056
# CSTR_keyphrase3_GCN               0.7469 + 0.09  0.7256 + 0.063
# Dmoz_Computers_keyphrase23_GAT   0.4087 + 0.015  0.4237 + 0.019
# Dmoz_Computers_keyphrase23_GCN   0.3896 + 0.015  0.4022 + 0.018
# Dmoz_Computers_keyphrase2_GAT     0.4068 + 0.01  0.4174 + 0.017
# Dmoz_Computers_keyphrase2_GCN    0.3771 + 0.017  0.3959 + 0.014
# Dmoz_Computers_keyphrase3_GAT    0.4149 + 0.014  0.4271 + 0.018
# Dmoz_Computers_keyphrase3_GCN    0.3989 + 0.019   0.4106 + 0.01
# Dmoz_Health_keyphrase23_GAT      0.6744 + 0.024   0.6791 + 0.02
# ...

# %%
df_f1[36:72]
# Out:
#                                        LLM_only               1  \
# Dataframe
# NSF_keyphrase23_GAT              0.5848 + 0.037  0.6043 + 0.035
# NSF_keyphrase23_GCN              0.5868 + 0.042  0.6022 + 0.037
# NSF_keyphrase2_GAT               0.5851 + 0.036  0.6035 + 0.038
# NSF_keyphrase2_GCN               0.5789 + 0.031  0.5914 + 0.032
# NSF_keyphrase3_GAT               0.5877 + 0.039  0.6079 + 0.028
# NSF_keyphrase3_GCN               0.5888 + 0.038  0.6119 + 0.022
# SyskillWebert_keyphrase23_GAT    0.6212 + 0.031  0.6348 + 0.029
# SyskillWebert_keyphrase23_GCN    0.5785 + 0.045  0.6182 + 0.035
# SyskillWebert_keyphrase2_GAT     0.6219 + 0.031  0.6245 + 0.024
# SyskillWebert_keyphrase2_GCN     0.6213 + 0.056  0.6151 + 0.044
# SyskillWebert_keyphrase3_GAT     0.6156 + 0.028    0.626 + 0.03
# SyskillWebert_keyphrase3_GCN     0.5968 + 0.035  0.6031 + 0.041
# classic4_keyphrase23_GAT         0.7633 + 0.107  0.7772 + 0.099
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
df_f1["LLM_only"]   = round(df_f1_mean["LLM_only"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["LLM_only"], 3).astype(str)
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
lista = [df_f1]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', 'LLM_only','1',	'5',	'10',	'20',	'30',	'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

lista = [df_f1_mean]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # LLM 50

# %%
input_path ='/content/drive/MyDrive/Resultados/LLM/50/tabelas/'
output_path ='/content/drive/MyDrive/Resultados/LLM/50/tabelas/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
df_acc["LLM_only"]   = round(df_acc_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_acc_std["LLM_only"], 3).astype(str)
df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
df_pre["LLM_only"]   = round(df_pre_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_pre_std["LLM_only"], 3).astype(str)
df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
df_rec["LLM_only"]   = round(df_rec_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_rec_std["LLM_only"], 3).astype(str)
df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
df_f1["LLM_only"]   = round(df_f1_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_f1_std["LLM_only"], 3).astype(str)
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
df_sup["LLM_only"]   = round(df_sup_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_sup_std["LLM_only"], 3).astype(str)
df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
df_time["LLM_only"]   = round(df_time_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_time_std["LLM_only"], 3).astype(str)
df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                        LLM_only               1  \
# Dataframe
# CSTR_keyphrase23_GAT             0.7584 + 0.008  0.7584 + 0.019
# CSTR_keyphrase23_GCN             0.7692 + 0.027  0.7552 + 0.039
# CSTR_keyphrase2_GAT              0.7571 + 0.015  0.7597 + 0.017
# CSTR_keyphrase2_GCN              0.7674 + 0.025  0.7596 + 0.028
# CSTR_keyphrase3_GAT              0.7596 + 0.016   0.7562 + 0.02
# CSTR_keyphrase3_GCN              0.7495 + 0.043  0.7574 + 0.032
# Dmoz_Computers_keyphrase23_GAT   0.4558 + 0.006   0.4561 + 0.01
# Dmoz_Computers_keyphrase23_GCN   0.4356 + 0.008  0.4351 + 0.007
# Dmoz_Computers_keyphrase2_GAT    0.4528 + 0.009  0.4554 + 0.009
# Dmoz_Computers_keyphrase2_GCN     0.428 + 0.008  0.4292 + 0.007
# Dmoz_Computers_keyphrase3_GAT    0.4577 + 0.009  0.4599 + 0.007
# Dmoz_Computers_keyphrase3_GCN    0.4391 + 0.007  0.4408 + 0.006
# Dmoz_Health_keyphrase23_GAT       0.7174 + 0.02  0.7215 + 0.018
# ...

# %%
df_f1[36:72]
# Out:
#                                        LLM_only               1  \
# Dataframe
# NSF_keyphrase23_GAT               0.605 + 0.025  0.6043 + 0.025
# NSF_keyphrase23_GCN              0.5916 + 0.023  0.5955 + 0.023
# NSF_keyphrase2_GAT               0.6031 + 0.023  0.6068 + 0.026
# NSF_keyphrase2_GCN               0.5922 + 0.021  0.5928 + 0.024
# NSF_keyphrase3_GAT               0.6015 + 0.027  0.6074 + 0.025
# NSF_keyphrase3_GCN               0.5901 + 0.026  0.6032 + 0.017
# SyskillWebert_keyphrase23_GAT    0.6136 + 0.014  0.6118 + 0.013
# SyskillWebert_keyphrase23_GCN     0.6126 + 0.02  0.6133 + 0.019
# SyskillWebert_keyphrase2_GAT     0.6103 + 0.015  0.6159 + 0.014
# SyskillWebert_keyphrase2_GCN     0.6283 + 0.019   0.595 + 0.056
# SyskillWebert_keyphrase3_GAT     0.6113 + 0.013  0.6116 + 0.015
# SyskillWebert_keyphrase3_GCN     0.6103 + 0.017   0.6094 + 0.03
# classic4_keyphrase23_GAT         0.7954 + 0.074  0.8058 + 0.075
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
df_f1["LLM_only"]   = round(df_f1_mean["LLM_only"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["LLM_only"], 3).astype(str)
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
lista = [df_f1]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', 'LLM_only', '1',	'5',	'10',	'20',	'30',	'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

lista = [df_f1_mean]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # LLM 100

# %%
input_path ='/content/drive/MyDrive/Resultados/LLM/100/tabelas/'
output_path ='/content/drive/MyDrive/Resultados/LLM/100/tabelas/mean+std/'

# %% [markdown]
# ## load

# %%
df_acc_mean  = pd.read_csv(input_path+"/mean/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_mean  = pd.read_csv(input_path+"/mean/df_pre.csv", index_col='Dataframe')  # precision
df_rec_mean  = pd.read_csv(input_path+"/mean/df_rec.csv", index_col='Dataframe')  # recall
df_f1_mean   = pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_mean  = pd.read_csv(input_path+"/mean/df_sup.csv", index_col='Dataframe')  # support
df_time_mean = pd.read_csv(input_path+"/mean/df_time.csv", index_col='Dataframe') # time

df_acc_std  = pd.read_csv(input_path+"/std/df_acc.csv", index_col='Dataframe')  # acuracia
df_pre_std  = pd.read_csv(input_path+"/std/df_pre.csv", index_col='Dataframe')  # precision
df_rec_std  = pd.read_csv(input_path+"/std/df_rec.csv", index_col='Dataframe')  # recall
df_f1_std   = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score
df_sup_std  = pd.read_csv(input_path+"/std/df_sup.csv", index_col='Dataframe')  # support
df_time_std = pd.read_csv(input_path+"/std/df_time.csv", index_col='Dataframe') # time

# %% [markdown]
#   ## Ajustes

# %%
# Cria coluna de media
df_acc_mean['media'] = df_acc_mean.mean(axis=1)
df_pre_mean['media'] = df_pre_mean.mean(axis=1)
df_rec_mean['media'] = df_rec_mean.mean(axis=1)
df_f1_mean['media'] = df_f1_mean.mean(axis=1)
df_sup_mean['media'] = df_sup_mean.mean(axis=1)
df_time_mean['media'] = df_time_mean.mean(axis=1)

df_acc_std['media'] = df_acc_std.mean(axis=1)
df_pre_std['media'] = df_pre_std.mean(axis=1)
df_rec_std['media'] = df_rec_std.mean(axis=1)
df_f1_std['media'] = df_f1_std.mean(axis=1)
df_sup_std['media'] = df_sup_std.mean(axis=1)
df_time_std['media'] = df_time_std.mean(axis=1)

# %%
df_acc = df_acc_mean
df_pre = df_pre_mean
df_rec = df_rec_mean
df_f1 = df_f1_mean
df_sup = df_sup_mean
df_time = df_time_mean

# %%
df_acc["LLM_only"]   = round(df_acc_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_acc_std["LLM_only"], 3).astype(str)
df_acc["1"]   = round(df_acc_mean["1"], 4).astype(str)   + ' + ' + round(df_acc_std["1"], 3).astype(str)
df_acc["5"]   = round(df_acc_mean["5"], 4).astype(str)   + ' + ' + round(df_acc_std["5"], 3).astype(str)
df_acc["10"]  = round(df_acc_mean["10"], 4).astype(str)  + ' + ' + round(df_acc_std["10"], 3).astype(str)
df_acc["20"]  = round(df_acc_mean["20"], 4).astype(str)  + ' + ' + round(df_acc_std["20"], 3).astype(str)
df_acc["30"]  = round(df_acc_mean["30"], 4).astype(str)  + ' + ' + round(df_acc_std["30"], 3).astype(str)
df_acc["media"] = round(df_acc_mean["media"], 4).astype(str) + ' + ' + round(df_acc_std["media"], 3).astype(str)

# %%
df_pre["LLM_only"]   = round(df_pre_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_pre_std["LLM_only"], 3).astype(str)
df_pre["1"]   = round(df_pre_mean["1"], 4).astype(str)   + ' + ' + round(df_pre_std["1"], 3).astype(str)
df_pre["5"]   = round(df_pre_mean["5"], 4).astype(str)   + ' + ' + round(df_pre_std["5"], 3).astype(str)
df_pre["10"]  = round(df_pre_mean["10"], 4).astype(str)  + ' + ' + round(df_pre_std["10"], 3).astype(str)
df_pre["20"]  = round(df_pre_mean["20"], 4).astype(str)  + ' + ' + round(df_pre_std["20"], 3).astype(str)
df_pre["30"]  = round(df_pre_mean["30"], 4).astype(str)  + ' + ' + round(df_pre_std["30"], 3).astype(str)
df_pre["media"] = round(df_pre_mean["media"], 4).astype(str) + ' + ' + round(df_pre_std["media"], 3).astype(str)

# %%
df_rec["LLM_only"]   = round(df_rec_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_rec_std["LLM_only"], 3).astype(str)
df_rec["1"]   = round(df_rec_mean["1"], 4).astype(str)   + ' + ' + round(df_rec_std["1"], 3).astype(str)
df_rec["5"]   = round(df_rec_mean["5"], 4).astype(str)   + ' + ' + round(df_rec_std["5"], 3).astype(str)
df_rec["10"]  = round(df_rec_mean["10"], 4).astype(str)  + ' + ' + round(df_rec_std["10"], 3).astype(str)
df_rec["20"]  = round(df_rec_mean["20"], 4).astype(str)  + ' + ' + round(df_rec_std["20"], 3).astype(str)
df_rec["30"]  = round(df_rec_mean["30"], 4).astype(str)  + ' + ' + round(df_rec_std["30"], 3).astype(str)
df_rec["media"] = round(df_rec_mean["media"], 4).astype(str) + ' + ' + round(df_rec_std["media"], 3).astype(str)

# %%
df_f1["LLM_only"]   = round(df_f1_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_f1_std["LLM_only"], 3).astype(str)
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + ' + ' + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + ' + ' + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + ' + ' + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + ' + ' + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + ' + ' + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + ' + ' + round(df_f1_std["media"], 3).astype(str)

# %%
df_sup["LLM_only"]   = round(df_sup_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_sup_std["LLM_only"], 3).astype(str)
df_sup["1"]   = round(df_sup_mean["1"], 4).astype(str)   + ' + ' + round(df_sup_std["1"], 3).astype(str)
df_sup["5"]   = round(df_sup_mean["5"], 4).astype(str)   + ' + ' + round(df_sup_std["5"], 3).astype(str)
df_sup["10"]  = round(df_sup_mean["10"], 4).astype(str)  + ' + ' + round(df_sup_std["10"], 3).astype(str)
df_sup["20"]  = round(df_sup_mean["20"], 4).astype(str)  + ' + ' + round(df_sup_std["20"], 3).astype(str)
df_sup["30"]  = round(df_sup_mean["30"], 4).astype(str)  + ' + ' + round(df_sup_std["30"], 3).astype(str)
df_sup["media"] = round(df_sup_mean["media"], 4).astype(str) + ' + ' + round(df_sup_std["media"], 3).astype(str)

# %%
df_time["LLM_only"]   = round(df_time_mean["LLM_only"], 4).astype(str)   + ' + ' + round(df_time_std["LLM_only"], 3).astype(str)
df_time["1"]   = round(df_time_mean["1"], 4).astype(str)   + ' + ' + round(df_time_std["1"], 3).astype(str)
df_time["5"]   = round(df_time_mean["5"], 4).astype(str)   + ' + ' + round(df_time_std["5"], 3).astype(str)
df_time["10"]  = round(df_time_mean["10"], 4).astype(str)  + ' + ' + round(df_time_std["10"], 3).astype(str)
df_time["20"]  = round(df_time_mean["20"], 4).astype(str)  + ' + ' + round(df_time_std["20"], 3).astype(str)
df_time["30"]  = round(df_time_mean["30"], 4).astype(str)  + ' + ' + round(df_time_std["30"], 3).astype(str)
df_time["media"] = round(df_time_mean["media"], 4).astype(str) + ' + ' + round(df_time_std["media"], 3).astype(str)

# %%
lista = [df_acc,df_pre,df_rec,df_f1,df_sup, df_time]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %% [markdown]
# ## Printa e salva

# %%
df_f1[0:36]
# Out:
#                                        LLM_only               1  \
# Dataframe
# CSTR_keyphrase23_GAT             0.7671 + 0.016  0.7677 + 0.018
# CSTR_keyphrase23_GCN             0.7977 + 0.044  0.7915 + 0.014
# CSTR_keyphrase2_GAT              0.7651 + 0.018  0.7626 + 0.016
# CSTR_keyphrase2_GCN              0.7916 + 0.014  0.7531 + 0.059
# CSTR_keyphrase3_GAT              0.7699 + 0.015  0.7716 + 0.015
# CSTR_keyphrase3_GCN               0.7991 + 0.03   0.7907 + 0.02
# Dmoz_Computers_keyphrase23_GAT   0.4561 + 0.006  0.4557 + 0.007
# Dmoz_Computers_keyphrase23_GCN   0.4385 + 0.006  0.4392 + 0.006
# Dmoz_Computers_keyphrase2_GAT     0.453 + 0.007   0.452 + 0.005
# Dmoz_Computers_keyphrase2_GCN    0.4333 + 0.008  0.4348 + 0.008
# Dmoz_Computers_keyphrase3_GAT    0.4577 + 0.007   0.457 + 0.008
# Dmoz_Computers_keyphrase3_GCN    0.4472 + 0.005  0.4443 + 0.005
# Dmoz_Health_keyphrase23_GAT       0.717 + 0.019  0.7183 + 0.019
# ...

# %%
df_f1[36:72]
# Out:
#                                        LLM_only               1  \
# Dataframe
# NSF_keyphrase23_GAT               0.617 + 0.039  0.6171 + 0.038
# NSF_keyphrase23_GCN              0.6014 + 0.033  0.6034 + 0.034
# NSF_keyphrase2_GAT               0.6147 + 0.038  0.6164 + 0.042
# NSF_keyphrase2_GCN               0.6023 + 0.037  0.6028 + 0.038
# NSF_keyphrase3_GAT                0.6176 + 0.04  0.6198 + 0.038
# NSF_keyphrase3_GCN               0.6092 + 0.036  0.6065 + 0.035
# SyskillWebert_keyphrase23_GAT     0.602 + 0.015  0.6055 + 0.015
# SyskillWebert_keyphrase23_GCN    0.6059 + 0.016  0.6152 + 0.025
# SyskillWebert_keyphrase2_GAT     0.6011 + 0.012  0.6011 + 0.016
# SyskillWebert_keyphrase2_GCN     0.6063 + 0.026   0.6143 + 0.03
# SyskillWebert_keyphrase3_GAT     0.6016 + 0.013  0.5978 + 0.014
# SyskillWebert_keyphrase3_GCN     0.6065 + 0.017   0.6019 + 0.02
# classic4_keyphrase23_GAT          0.7968 + 0.08  0.7974 + 0.082
# ...

# %%
# Saving dataframes
df_acc.to_csv(output_path+"df_acc.csv",index=True, index_label='Dataframe') # acuracia
df_pre.to_csv(output_path+"df_pre.csv",index=True, index_label='Dataframe') # precision
df_rec.to_csv(output_path+"df_rec.csv",index=True, index_label='Dataframe') # recall
df_f1.to_csv(output_path+"df_f1.csv",index=True, index_label='Dataframe')  # f1-score
df_sup.to_csv(output_path+"df_sup.csv",index=True, index_label='Dataframe') # support
df_time.to_csv(output_path+"df_time.csv",index=True, index_label='Dataframe') # time

# %% [markdown]
# ## Tabela do Artigo

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_std = pd.read_csv(input_path+"/std/df_f1.csv", index_col='Dataframe')   # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

df_f1_std['media'] = df_f1_std.mean(axis=1)

df_f1 = df_f1_mean

# %%
df_f1["LLM_only"]   = round(df_f1_mean["LLM_only"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["LLM_only"], 3).astype(str)
df_f1["1"]   = round(df_f1_mean["1"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["1"], 3).astype(str)
df_f1["5"]   = round(df_f1_mean["5"], 4).astype(str)   + " $\pm$ " + round(df_f1_std["5"], 3).astype(str)
df_f1["10"]  = round(df_f1_mean["10"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["10"], 3).astype(str)
df_f1["20"]  = round(df_f1_mean["20"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["20"], 3).astype(str)
df_f1["30"]  = round(df_f1_mean["30"], 4).astype(str)  + " $\pm$ " + round(df_f1_std["30"], 3).astype(str)
df_f1["media"] = round(df_f1_mean["media"], 4).astype(str) + " $\pm$ " + round(df_f1_std["media"], 3).astype(str)

# %%
lista = [df_f1]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = '-' # support
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = '-' # support

# %%
def ajust_table(df):
    keyphrase_dit = {"keyphrase2":"[2]","keyphrase23":"[2,3]","keyphrase3":"[3]"}
    for i in df.index:
        split = i.split('_')
        if len(split)==3:
            df.at[i,"Dataset"] = split[0]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[1]]
            df.at[i,"GNN Model"] = split[2]
        if len(split)==4:
            df.at[i,"Dataset"] = split[0]+'_'+split[1]
            df.at[i,"Keyphrases"] = keyphrase_dit[split[2]]
            df.at[i,"GNN Model"] = split[3]
    df = df[['Dataset',	'Keyphrases',	'GNN Model', 'LLM_only', '1',	'5',	'10',	'20',	'30',	'media']]
    return df

# %%
df_f1 = ajust_table(df_f1)

# %%
df_f1_mean= pd.read_csv(input_path+"/mean/df_f1.csv", index_col='Dataframe')    # f1-score

df_f1_mean['media'] = df_f1_mean.mean(axis=1)

lista = [df_f1_mean]

for i in lista:
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase2_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase3_GAT', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GCN', "30"] = 0 # support
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # acuracia
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # precision
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # recall
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # f1-score
    i.at['CSTR_keyphrase23_GAT', "30"] = 0 # support

# %%
lista_maximos = []
for i in range(12):
    l=i*6
    df = df_f1_mean[l:l+6]
    aux = df.idxmax(axis=0)
    for a,b in zip(list(aux.index),list(aux)):
        lista_maximos.append([b,a])

# %%
lista_valores_maximos = []
for i,j in lista_maximos:
    lista_valores_maximos.append(df_f1.loc[i,j])

# %% [markdown]
# ## Printa tabela

# %%
def highlight_max(x):
    return ['font-weight: bold' if v in lista_valores_maximos else ''
                for v in x]

df_f1.style.apply(highlight_max).hide()
# Out:
# <style type="text/css">
# ...
