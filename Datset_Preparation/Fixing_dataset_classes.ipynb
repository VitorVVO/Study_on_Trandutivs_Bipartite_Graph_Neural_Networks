# %% [markdown]
# # Setup

# %%
#!git clone https://github.com/rmarcacini/text-collections.git

# %%
# CSTR.csv
# Dmoz-Computers.csv
# Dmoz-Health.csv
# Dmoz-Science.csv
# Dmoz-Sports.csv
# Industry Sector.csv
# NSF.csv
# SyskillWebert.csv  - não precisa
# classic4.csv
# re8.csv
# review_polarity.csv
# webkb-parsed.csv

# %%
# re.search(r"[a-zA-Z_]*", 'Artificial_Intelligence_1434141.txt').group()
# re.search(r"^.*(?=_\d)", 'Artificial_Intelligence_1434141.txt').group()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os
import pickle as pkl
import re
# from keybert import KeyBERT

# %%
# for index, sample in df.iterrows():
#   print(sample['file_name'])
#   df['class'][index] = re.search(r"(conglomerates_industry|utilities|energy|healthcare|technology|transportation|consumer_non_cyclical|capital_goods|basic_materials|financial|consumer_cyclical|services)",
#                                  df['file_name'][index]).group()

# %% [markdown]
# # Dmoz_Computers

# %%
def concerta(x):
    return re.search(r"^.*(?=_\d)", x).group()

# %%
dataset_name = "Dmoz_Computers"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id                            file_name  \
# 0   0  Artificial_Intelligence_1434272.txt
# 1   1  Artificial_Intelligence_1433615.txt
# 2   2  Artificial_Intelligence_1434400.txt
# 3   3  Artificial_Intelligence_1434281.txt
# 4   4  Artificial_Intelligence_1434141.txt
#
#                                                 text       class  \
# 0  Principal Curves Page Introduction to principa...  Artificial
# 1  Iowa State University - Artificial Intelligenc...  Artificial
# 2  Paccanaro, Alberto Learning distributed repres...  Artificial
# 3  Attrasoft Provider of a number of neural netwo...  Artificial
# 4  LibML A machine learning library. New implemen...  Artificial
#
#                                           keyphrase2  \
# 0  [(principal curves, 0.7236), (curves summary, ...
# 1  [(university artificial, 0.5531), (intelligenc...
# 2  [(concepts relational, 0.5298), (distributed r...
# 3  [(sound recognition, 0.5352), (attrasoft provi...
# ...

# %%
df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id                            file_name  \
# 0   0  Artificial_Intelligence_1434272.txt
# 1   1  Artificial_Intelligence_1433615.txt
# 2   2  Artificial_Intelligence_1434400.txt
# 3   3  Artificial_Intelligence_1434281.txt
# 4   4  Artificial_Intelligence_1434141.txt
#
#                                                 text                    class  \
# 0  Principal Curves Page Introduction to principa...  Artificial_Intelligence
# 1  Iowa State University - Artificial Intelligenc...  Artificial_Intelligence
# 2  Paccanaro, Alberto Learning distributed repres...  Artificial_Intelligence
# 3  Attrasoft Provider of a number of neural netwo...  Artificial_Intelligence
# 4  LibML A machine learning library. New implemen...  Artificial_Intelligence
#
#                                           keyphrase2  \
# 0  [(principal curves, 0.7236), (curves summary, ...
# 1  [(university artificial, 0.5531), (intelligenc...
# 2  [(concepts relational, 0.5298), (distributed r...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index()
# Out:
# ['Artificial_Intelligence', 'CAD_and_CAM', 'Companies', 'Computer_Science', 'Consultants', 'Data_Communications', 'Data_Formats', 'Education', 'Graphics', 'Hardware', 'Internet', 'Mobile_Computing', 'Multimedia', 'Open_Source', 'Programming', 'Robotics', 'Security', 'Software', 'Systems']
# 19
# class
# Artificial_Intelligence    500
# CAD_and_CAM                500
# Companies                  500
# Computer_Science           500
# Consultants                500
# Data_Communications        500
# Data_Formats               500
# Education                  500
# Graphics                   500
# Hardware                   500
# Internet                   500
# Mobile_Computing           500
# Multimedia                 500
# Open_Source                500
# Programming                500
# Robotics                   500
# Security                   500
# Software                   500
# Systems                    500
# Name: count, dtype: int64

# %%
df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # Dmoz_Health

# %%
dataset_name = "Dmoz_Health"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id               file_name  \
# 0   0  Addictions_1578510.txt
# 1   1  Addictions_1577747.txt
# 2   2  Addictions_1578166.txt
# 3   3  Addictions_1577381.txt
# 4   4  Addictions_1578793.txt
#
#                                                 text       class  \
# 0  Illinois Church Action on Alcohol and Addictio...  Addictions
# 1  AA Statewide Meeting lists for all of Vermont....  Addictions
# 2  Gracer Medical Group Dr. Richard Gracer is a p...  Addictions
# 3  Phoenix Meetings, events, and visitor informat...  Addictions
# 4  American River Area Narcotics Anonymous Resour...  Addictions
#
#                                           keyphrase2  \
# 0  [(illinois church, 0.6463), (groups illinois, ...
# 1  [(alcoholics anonymous, 0.6022), (lists vermon...
# 2  [(richard gracer, 0.7271), (gracer medical, 0....
# 3  [(phoenix meetings, 0.5868), (mesa phoenix, 0....
# 4  [(narcotics anonymous, 0.5901), (addiction sac...
#
#                                           keyphrase3  \
# ...

# %%
df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id               file_name  \
# 0   0  Addictions_1578510.txt
# 1   1  Addictions_1577747.txt
# 2   2  Addictions_1578166.txt
# 3   3  Addictions_1577381.txt
# 4   4  Addictions_1578793.txt
#
#                                                 text       class  \
# 0  Illinois Church Action on Alcohol and Addictio...  Addictions
# 1  AA Statewide Meeting lists for all of Vermont....  Addictions
# 2  Gracer Medical Group Dr. Richard Gracer is a p...  Addictions
# 3  Phoenix Meetings, events, and visitor informat...  Addictions
# 4  American River Area Narcotics Anonymous Resour...  Addictions
#
#                                           keyphrase2  \
# 0  [(illinois church, 0.6463), (groups illinois, ...
# 1  [(alcoholics anonymous, 0.6022), (lists vermon...
# 2  [(richard gracer, 0.7271), (gracer medical, 0....
# 3  [(phoenix meetings, 0.5868), (mesa phoenix, 0....
# 4  [(narcotics anonymous, 0.5901), (addiction sac...
#
#                                           keyphrase3  \
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index()
# Out:
# ['Addictions', 'Alternative', 'Animal', 'Conditions_and_Diseases', 'Medicine', 'Mental_Health', 'Nursing', 'Nutrition', 'Pharmacy', 'Professions', 'Public_Health_and_Safety', 'Reproductive_Health', 'Senior_Health']
# 13
# class
# Addictions                  500
# Alternative                 500
# Animal                      500
# Conditions_and_Diseases     500
# Medicine                    500
# Mental_Health               500
# Nursing                     500
# Nutrition                   500
# Pharmacy                    500
# Professions                 500
# Public_Health_and_Safety    500
# Reproductive_Health         500
# Senior_Health               500
# Name: count, dtype: int64

# %%
df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # Dmoz_Science

# %%
dataset_name = "Dmoz_Science"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id                file_name  \
# 0   0  Agriculture_2786497.txt
# 1   1  Agriculture_2784741.txt
# 2   2  Agriculture_2785016.txt
# 3   3  Agriculture_2786133.txt
# 4   4  Agriculture_2786989.txt
#
#                                                 text        class  \
# 0  Texas A&amp;M Horticultural Extension - Vegeta...  Agriculture
# 1  Algaculture Information from Wikipedia on this...  Agriculture
# 2  Annual Canarygrass Factsheet on this grain cro...  Agriculture
# 3  Black Sigatoka Photographs and information on ...  Agriculture
# 4  Irrigation Training and Research Center Univer...  Agriculture
#
#                                           keyphrase2  \
# 0  [(extension vegetables, 0.6118), (newsletters ...
# 1  [(production microalgae, 0.7194), (algaculture...
# 2  [(annual canarygrass, 0.7755), (canarygrass fa...
# 3  [(disease bananas, 0.681), (fungal disease, 0....
# 4  [(irrigation training, 0.8181), (focusing irri...
#
# ...

# %%
df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id                file_name  \
# 0   0  Agriculture_2786497.txt
# 1   1  Agriculture_2784741.txt
# 2   2  Agriculture_2785016.txt
# 3   3  Agriculture_2786133.txt
# 4   4  Agriculture_2786989.txt
#
#                                                 text        class  \
# 0  Texas A&amp;M Horticultural Extension - Vegeta...  Agriculture
# 1  Algaculture Information from Wikipedia on this...  Agriculture
# 2  Annual Canarygrass Factsheet on this grain cro...  Agriculture
# 3  Black Sigatoka Photographs and information on ...  Agriculture
# 4  Irrigation Training and Research Center Univer...  Agriculture
#
#                                           keyphrase2  \
# 0  [(extension vegetables, 0.6118), (newsletters ...
# 1  [(production microalgae, 0.7194), (algaculture...
# 2  [(annual canarygrass, 0.7755), (canarygrass fa...
# 3  [(disease bananas, 0.681), (fungal disease, 0....
# 4  [(irrigation training, 0.8181), (focusing irri...
#
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index()
# Out:
# ['Agriculture', 'Astronomy', 'Biology', 'Chemistry', 'Earth_Sciences', 'Environment', 'Instruments_and_Supplies', 'Math', 'Physics', 'Science_in_Society', 'Social_Sciences', 'Technology']
# 12
# class
# Agriculture                 500
# Astronomy                   500
# Biology                     500
# Chemistry                   500
# Earth_Sciences              500
# Environment                 500
# Instruments_and_Supplies    500
# Math                        500
# Physics                     500
# Science_in_Society          500
# Social_Sciences             500
# Technology                  500
# Name: count, dtype: int64

# %%
df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # Dmoz_Sports

# %%
dataset_name = "Dmoz_Sports"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id             file_name  \
# 0   0  Baseball_3191005.txt
# 1   1  Baseball_3193010.txt
# 2   2  Baseball_3190744.txt
# 3   3  Baseball_3193695.txt
# 4   4  Baseball_3193486.txt
#
#                                                 text     class  \
# 0  Bryant Bulldogs Official site with news, sched...  Baseball
# 1  Hirschbeck v. Alomar Covers a legal case betwe...  Baseball
# 2  Mountaineers Baseball Official site. Includes ...  Baseball
# 3  M.S.H. Little League Contains news items, a li...  Baseball
# 4  Quotations: Bob Uecker Baseball Almanac collec...  Baseball
#
#                                           keyphrase2  \
# 0  [(bryant bulldogs, 0.8054), (bulldogs official...
# 1  [(legal case, 0.5041), (hirschbeck alomar, 0.4...
# 2  [(mountaineers baseball, 0.7208), (official si...
# 3  [(little league, 0.6328), (listing teams, 0.50...
# 4  [(quotes ballplayer, 0.6472), (quotations bob,...
#
#                                           keyphrase3  \
# ...

# %%
df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id             file_name  \
# 0   0  Baseball_3191005.txt
# 1   1  Baseball_3193010.txt
# 2   2  Baseball_3190744.txt
# 3   3  Baseball_3193695.txt
# 4   4  Baseball_3193486.txt
#
#                                                 text     class  \
# 0  Bryant Bulldogs Official site with news, sched...  Baseball
# 1  Hirschbeck v. Alomar Covers a legal case betwe...  Baseball
# 2  Mountaineers Baseball Official site. Includes ...  Baseball
# 3  M.S.H. Little League Contains news items, a li...  Baseball
# 4  Quotations: Bob Uecker Baseball Almanac collec...  Baseball
#
#                                           keyphrase2  \
# 0  [(bryant bulldogs, 0.8054), (bulldogs official...
# 1  [(legal case, 0.5041), (hirschbeck alomar, 0.4...
# 2  [(mountaineers baseball, 0.7208), (official si...
# 3  [(little league, 0.6328), (listing teams, 0.50...
# 4  [(quotes ballplayer, 0.6472), (quotations bob,...
#
#                                           keyphrase3  \
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index()
# Out:
# ['Baseball', 'Basketball', 'Bowling', 'Cricket', 'Cycling', 'Equestrian', 'Fencing', 'Flying_Discs', 'Football', 'Golf', 'Gymnastics', 'Hockey', 'Lacrosse', 'Martial_Arts', 'Motorsports', 'Paintball', 'Running', 'Skating', 'Soccer', 'Softball', 'Strength_Sports', 'Tennis', 'Track_and_Field', 'Volleyball', 'Water_Sports', 'Winter_Sports', 'Wrestling']
# 27
# class
# Baseball           500
# Basketball         500
# Bowling            500
# Cricket            500
# Cycling            500
# Equestrian         500
# Fencing            500
# Flying_Discs       500
# Football           500
# Golf               500
# Gymnastics         500
# Hockey             500
# Lacrosse           500
# Martial_Arts       500
# Motorsports        500
# Paintball          500
# Running            500
# Skating            500
# Soccer             500
# Softball           500
# Strength_Sports    500
# Tennis             500
# Track_and_Field    500
# Volleyball         500
# Water_Sports       500
# ...

# %%
df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # classic4 - no change - classes were already correct

# %%
dataset_name = "classic4"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
#df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id         file_name                                               text  \
# 0   0  cacm_cacm.001232  Representation of the Standard ECMA 7-Bit Code...
# 1   1  cacm_cacm.002901  An Encoding Method for Multifield Sorting and ...
# 2   2  cacm_cacm.003171  Line Numbers Made Cheap A technique is describ...
# 3   3  cacm_cacm.001938  Some Criteria for Time-Sharing System Performa...
# 4   4  cacm_cacm.000233        Abstracts-Additional Nuclear Reactor Codes
#
#   class                                         keyphrase2  \
# 0  cacm  [(cards ecma, 0.6013), (standard ecma, 0.5788)...
# 1  cacm  [(strings order, 0.6238), (multifield sorting,...
# 2  cacm  [(line numbers, 0.6122), (line number, 0.5592)...
# 3  cacm  [(time sharing, 0.6189), (sharing performance,...
# 4  cacm  [(reactor codes, 0.8534), (nuclear reactor, 0....
#
#                                           keyphrase3  \
# 0  [(ecma bit code, 0.7377), (punched cards ecma,...
# ...

# %%
#df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id         file_name                                               text  \
# 0   0  cacm_cacm.001232  Representation of the Standard ECMA 7-Bit Code...
# 1   1  cacm_cacm.002901  An Encoding Method for Multifield Sorting and ...
# 2   2  cacm_cacm.003171  Line Numbers Made Cheap A technique is describ...
# 3   3  cacm_cacm.001938  Some Criteria for Time-Sharing System Performa...
# 4   4  cacm_cacm.000233        Abstracts-Additional Nuclear Reactor Codes
#
#   class                                         keyphrase2  \
# 0  cacm  [(cards ecma, 0.6013), (standard ecma, 0.5788)...
# 1  cacm  [(strings order, 0.6238), (multifield sorting,...
# 2  cacm  [(line numbers, 0.6122), (line number, 0.5592)...
# 3  cacm  [(time sharing, 0.6189), (sharing performance,...
# 4  cacm  [(reactor codes, 0.8534), (nuclear reactor, 0....
#
#                                           keyphrase3  \
# 0  [(ecma bit code, 0.7377), (punched cards ecma,...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index()
# Out:
# ['cacm', 'cisi', 'cran', 'med']
# 4
# class
# cacm    3204
# cisi    1460
# cran    1398
# med     1033
# Name: count, dtype: int64

# %%
# df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # CSTR - no change - classes were already correct

# %%
dataset_name = "CSTR"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id                        file_name  \
# 0   0  ArtificiallIntelligence_126.txt
# 1   1    ArtificiallIntelligence_5.txt
# 2   2   ArtificiallIntelligence_48.txt
# 3   3   ArtificiallIntelligence_81.txt
# 4   4   ArtificiallIntelligence_25.txt
#
#                                                 text                    class  \
# 0  Rhetorical (Rhet) is a programming / knowledge...  ArtificiallIntelligence
# 1  Reduction is the operation of transforming a p...  ArtificiallIntelligence
# 2  For years, researchers have used knowledge-int...  ArtificiallIntelligence
# 3  Proceedings of a workshop held in conjunction ...  ArtificiallIntelligence
# 4  The Medication Advisor is the latest project o...  ArtificiallIntelligence
#
#                                           keyphrase2  \
# 0  [(rhetorical rhet, 0.7475), (rhet programming,...
# 1  [(parsing complexity, 0.5977), (transformed gr...
# 2  [(disambiguating parsing, 0.7122), (syntactic ...
# ...

# %%
#df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id                        file_name  \
# 0   0  ArtificiallIntelligence_126.txt
# 1   1    ArtificiallIntelligence_5.txt
# 2   2   ArtificiallIntelligence_48.txt
# 3   3   ArtificiallIntelligence_81.txt
# 4   4   ArtificiallIntelligence_25.txt
#
#                                                 text                    class  \
# 0  Rhetorical (Rhet) is a programming / knowledge...  ArtificiallIntelligence
# 1  Reduction is the operation of transforming a p...  ArtificiallIntelligence
# 2  For years, researchers have used knowledge-int...  ArtificiallIntelligence
# 3  Proceedings of a workshop held in conjunction ...  ArtificiallIntelligence
# 4  The Medication Advisor is the latest project o...  ArtificiallIntelligence
#
#                                           keyphrase2  \
# 0  [(rhetorical rhet, 0.7475), (rhet programming,...
# 1  [(parsing complexity, 0.5977), (transformed gr...
# 2  [(disambiguating parsing, 0.7122), (syntactic ...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index()
# Out:
# ['ArtificiallIntelligence', 'Robotics', 'Systems', 'Theory']
# 4
# class
# ArtificiallIntelligence    128
# Robotics                   100
# Systems                     25
# Theory                      46
# Name: count, dtype: int64

# %%
# df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # Industry_Sector

# %%
# conglomerates_industry|utilities|energy|healthcare|technology|transportation|consumer_non-cyclical|capital_goods|basic_materials|financial|consumer_cyclical|services
#re.search(r"^.*(?=_http)", "utilities_http:^^www.wstnres.com^").group()
def concerta(x):
    return re.search(r"(conglomerates_industry|utilities|energy|healthcare|technology|transportation|consumer_non-cyclical|capital_goods|basic_materials|financial|consumer_cyclical|services)", x).group()

# %%
dataset_name = "Industry_Sector"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id                                          file_name  \
# 0   0        basic_materials_http:^^www.littonacdipe.com
# 1   1  basic_materials_http:^^www.weirton.com^contact...
# 2   2  basic_materials_http:^^home.earthlink.net^~nuc...
# 3   3    basic_materials_http:^^www.useg.com^invest.html
# 4   4  basic_materials_http:^^www.terraindustries.com...
#
#                                                 text  class  \
# 0     Litton            Litton: Interconnect Prod...  basic
# 1  Allow: GET, HEAD URI:       Contact Weirton St...  basic
# 2      Systems     Which system would you choose?...  basic
# 3         US Energy Corporation Investor News    ...  basic
# 4        Terra Industries, Inc., Company Informat...  basic
#
#                                           keyphrase2  \
# 0  [(packaging esp, 0.5861), (litton interconnect...
# 1  [(contact firm, 0.562), (contact weirton, 0.50...
# 2  [(pressure cylinders, 0.6841), (pressure bulk,...
# ...

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id                                          file_name  \
# 0   0        basic_materials_http:^^www.littonacdipe.com
# 1   1  basic_materials_http:^^www.weirton.com^contact...
# 2   2  basic_materials_http:^^home.earthlink.net^~nuc...
# 3   3    basic_materials_http:^^www.useg.com^invest.html
# 4   4  basic_materials_http:^^www.terraindustries.com...
#
#                                                 text            class  \
# 0     Litton            Litton: Interconnect Prod...  basic_materials
# 1  Allow: GET, HEAD URI:       Contact Weirton St...  basic_materials
# 2      Systems     Which system would you choose?...  basic_materials
# 3         US Energy Corporation Investor News    ...  basic_materials
# 4        Terra Industries, Inc., Company Informat...  basic_materials
#
#                                           keyphrase2  \
# 0  [(packaging esp, 0.5861), (litton interconnect...
# 1  [(contact firm, 0.562), (contact weirton, 0.50...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index().sort_values()
# Out:
# ['basic_materials', 'capital_goods', 'conglomerates_industry', 'consumer_cyclical', 'consumer_non-cyclical', 'energy', 'financial', 'healthcare', 'services', 'technology', 'transportation', 'utilities']
# 12
# class
# conglomerates_industry     100
# utilities                  282
# energy                     354
# healthcare                 397
# technology                 495
# transportation             505
# consumer_non-cyclical      557
# capital_goods              635
# basic_materials            947
# financial                  959
# consumer_cyclical          991
# services                  2595
# Name: count, dtype: int64

# %%
df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # NSF

# %%
#gravitional_theory|metals|neuroscience|networking|hydro|data_management|theory_computing|software_engineering|politic|statistics|sociology|ecology|oceanography|geophysics|math|economic
def concerta(x):
    return re.search(r"gravitional_theory|metals|neuroscience|networking|hydro|data_management|theory_computing|software_engineering|politic|statistics|sociology|ecology|oceanography|geophysics|math|economic", x).group()

# %%
dataset_name = "NSF"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
#df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id                                file_name  \
# 0   0  management_data_management.a9820721.txt
# 1   1  management_data_management.a9116988.txt
# 2   2  management_data_management.a9457613.txt
# 3   3  management_data_management.a9734191.txt
# 4   4  management_data_management.a9116798.txt
#
#                                                 text class  \
# 0  an intelligent visual database system hierarch...  data
# 1  spatio-temporal database management for global...  data
# 2  nyi theory and implementation of declarative d...  data
# 3  pecase providing a coherent view of diverse di...  data
# 4  an object-oriented toolbox for use with the pr...  data
#
#                                           keyphrase2  \
# 0  [(description matching, 0.5734), (integrated s...
# 1  [(temporal database, 0.6222), (database manage...
# 2  [(declarative database, 0.715), (database syst...
# 3  [(pecase providing, 0.5841), (diverse distribu...
# ...

# %%
df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id                                file_name  \
# 0   0  management_data_management.a9820721.txt
# 1   1  management_data_management.a9116988.txt
# 2   2  management_data_management.a9457613.txt
# 3   3  management_data_management.a9734191.txt
# 4   4  management_data_management.a9116798.txt
#
#                                                 text            class  \
# 0  an intelligent visual database system hierarch...  data_management
# 1  spatio-temporal database management for global...  data_management
# 2  nyi theory and implementation of declarative d...  data_management
# 3  pecase providing a coherent view of diverse di...  data_management
# 4  an object-oriented toolbox for use with the pr...  data_management
#
#                                           keyphrase2  \
# 0  [(description matching, 0.5734), (integrated s...
# 1  [(temporal database, 0.6222), (database manage...
# 2  [(declarative database, 0.715), (database syst...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_index().sort_values()
# Out:
# ['data_management', 'ecology', 'economic', 'geophysics', 'gravitional_theory', 'hydro', 'math', 'metals', 'networking', 'neuroscience', 'oceanography', 'politic', 'sociology', 'software_engineering', 'statistics', 'theory_computing']
# 16
# class
# gravitional_theory       130
# metals                   201
# neuroscience             307
# networking               345
# hydro                    355
# data_management          402
# theory_computing         442
# software_engineering     524
# politic                  603
# statistics               647
# sociology                739
# ecology                  889
# oceanography             990
# geophysics              1202
# math                    1339
# economic                1409
# Name: count, dtype: int64

# %%
df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # re8 - no change - classes were already correct

# %%
dataset_name = "re8"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
#df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id     file_name                                               text class  \
# 0   0  acq.4342.txt  mcdowell me to merger with interpharm inc mcdo...   acq
# 1   1  acq.5302.txt  intermagnetics general inma completes buy inte...   acq
# 2   2  acq.8530.txt  tesco extends hillards offer tesco plc tsco l ...   acq
# 3   3  acq.3841.txt  healthvest hvt sells shares healthvest a maryl...   acq
# 4   4  acq.6302.txt  cooper canada said it received takeover offers...   acq
#
#                                           keyphrase2  \
# 0  [(pct interpharm, 0.6568), (interpharm pct, 0....
# 1  [(buy intermagnetics, 0.5958), (intermagnetics...
# 2  [(tesco plc, 0.5533), (offer tesco, 0.5289), (...
# 3  [(shares healthvest, 0.6659), (hvt sells, 0.63...
# 4  [(takeover offers, 0.6083), (received takeover...
#
#                                           keyphrase3  \
# 0  [(mcdowell merger interpharm, 0.7512), (acquir...
# 1  [(completes buy intermagnetics, 0.6764), (inte...
# ...

# %%
#df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id     file_name                                               text class  \
# 0   0  acq.4342.txt  mcdowell me to merger with interpharm inc mcdo...   acq
# 1   1  acq.5302.txt  intermagnetics general inma completes buy inte...   acq
# 2   2  acq.8530.txt  tesco extends hillards offer tesco plc tsco l ...   acq
# 3   3  acq.3841.txt  healthvest hvt sells shares healthvest a maryl...   acq
# 4   4  acq.6302.txt  cooper canada said it received takeover offers...   acq
#
#                                           keyphrase2  \
# 0  [(pct interpharm, 0.6568), (interpharm pct, 0....
# 1  [(buy intermagnetics, 0.5958), (intermagnetics...
# 2  [(tesco plc, 0.5533), (offer tesco, 0.5289), (...
# 3  [(shares healthvest, 0.6659), (hvt sells, 0.63...
# 4  [(takeover offers, 0.6083), (received takeover...
#
#                                           keyphrase3  \
# 0  [(mcdowell merger interpharm, 0.7512), (acquir...
# 1  [(completes buy intermagnetics, 0.6764), (inte...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_values()
# Out:
# ['acq', 'crude', 'earn', 'grain', 'interest', 'money', 'ship', 'trade']
# 8
# class
# grain         51
# ship         144
# interest     271
# money        293
# trade        326
# crude        374
# acq         2292
# earn        3923
# Name: count, dtype: int64

# %%
# df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # review_polarity - no change - classes were already correct

# %%
dataset_name = "review_polarity"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
#df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id        file_name                                               text  \
# 0   0  cv145_12239.txt  it was once said that in order to truly enjoy ...
# 1   1  cv745_14009.txt  conventional wisdom among collectibles retaile...
# 2   2  cv376_20883.txt  robin williams has the rarest of gifts : the a...
# 3   3  cv109_22599.txt  nearly every film tim burton has directed has ...
# 4   4  cv494_18689.txt  you know , i never really wondered what the ta...
#
#   class                                         keyphrase2  \
# 0   neg  [(shawshank redemption, 0.4308), (overwhelms h...
# 1   neg  [(nostalgia nowadays, 0.4483), (yore hollywood...
# 2   neg  [(robin williams, 0.509), (jakob liar, 0.5062)...
# 3   neg  [(sleepy hollow, 0.6049), (hollow movie, 0.548...
# 4   neg  [(movies tarzan, 0.5787), (tarzan films, 0.574...
#
#                                           keyphrase3  \
# 0  [(huntingburg indiana film, 0.4553), (played t...
# 1  [(toys late sixties, 0.5266), (heavy nostalgia...
# ...

# %%
#df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id        file_name                                               text  \
# 0   0  cv145_12239.txt  it was once said that in order to truly enjoy ...
# 1   1  cv745_14009.txt  conventional wisdom among collectibles retaile...
# 2   2  cv376_20883.txt  robin williams has the rarest of gifts : the a...
# 3   3  cv109_22599.txt  nearly every film tim burton has directed has ...
# 4   4  cv494_18689.txt  you know , i never really wondered what the ta...
#
#   class                                         keyphrase2  \
# 0   neg  [(shawshank redemption, 0.4308), (overwhelms h...
# 1   neg  [(nostalgia nowadays, 0.4483), (yore hollywood...
# 2   neg  [(robin williams, 0.509), (jakob liar, 0.5062)...
# 3   neg  [(sleepy hollow, 0.6049), (hollow movie, 0.548...
# 4   neg  [(movies tarzan, 0.5787), (tarzan films, 0.574...
#
#                                           keyphrase3  \
# 0  [(huntingburg indiana film, 0.4553), (played t...
# 1  [(toys late sixties, 0.5266), (heavy nostalgia...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_values()
# Out:
# ['neg', 'pos']
# 2
# class
# neg    1000
# pos    1000
# Name: count, dtype: int64

# %%
# df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # SyskillWebert - no change - classes were already correct

# %%
dataset_name = "SyskillWebert"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
#df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id file_name                                               text  class  \
# 0   0        53    LaFond, Lois        One World              (...  Bands
# 1   1        28    Houston, Penelope   Houston, Penelope       ...  Bands
# 2   2        57    Bernard, Mary Ellen   Bernard, Mary Ellen   ...  Bands
# 3   3        25    Deth Specula   Deth Specula         Careenin...  Bands
# 4   4        15    Hungry Ghost   Hungry Ghost         Aboral  ...  Bands
#
#                                           keyphrase2  \
# 0  [(songs lafond, 0.5778), (rockadile music, 0.5...
# 1  [(penelope houston, 0.6083), (houston penelope...
# 2  [(latvia listeners, 0.529), (radio riga, 0.457...
# 3  [(deth specula, 0.5982), (specula deth, 0.5812...
# 4  [(ghost hungry, 0.6302), (hungry ghost, 0.6258...
#
#                                           keyphrase3  \
# 0  [(lafond rockadiles songs, 0.6489), (world chi...
# 1  [(music avengers penelope, 0.6799), (band aven...
# ...

# %%
#df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id file_name                                               text  class  \
# 0   0        53    LaFond, Lois        One World              (...  Bands
# 1   1        28    Houston, Penelope   Houston, Penelope       ...  Bands
# 2   2        57    Bernard, Mary Ellen   Bernard, Mary Ellen   ...  Bands
# 3   3        25    Deth Specula   Deth Specula         Careenin...  Bands
# 4   4        15    Hungry Ghost   Hungry Ghost         Aboral  ...  Bands
#
#                                           keyphrase2  \
# 0  [(songs lafond, 0.5778), (rockadile music, 0.5...
# 1  [(penelope houston, 0.6083), (houston penelope...
# 2  [(latvia listeners, 0.529), (radio riga, 0.457...
# 3  [(deth specula, 0.5982), (specula deth, 0.5812...
# 4  [(ghost hungry, 0.6302), (hungry ghost, 0.6258...
#
#                                           keyphrase3  \
# 0  [(lafond rockadiles songs, 0.6489), (world chi...
# 1  [(music avengers penelope, 0.6799), (band aven...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_values()
# Out:
# ['Bands', 'BioMedical', 'Goats', 'Sheep']
# 4
# class
# Bands          61
# Sheep          65
# Goats          70
# BioMedical    137
# Name: count, dtype: int64

# %%
# df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')

# %% [markdown]
# # webkb_parsed - no change - classes were already correct

# %%
dataset_name = "webkb_parsed"

# %%
df = pd.read_pickle("/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/"+dataset_name+"/"+dataset_name+".csv")

# %%
#df['file_name'] = df['class'] + '_' + df['file_name']

# %%
df.head()
# Out:
#    id                                          file_name  \
# 0   0  http:^^www.cs.utexas.edu^users^dahlin^Classes^...
# 1   1   http:^^www.cs.rutgers.edu^~venugopa^112^112.html
# 2   2  http:^^www.eecs.umich.edu^courses^eecs661^eecs...
# 3   3     http:^^www.cis.upenn.edu^~cse110e^cse110e.html
# 4   4  http:^^www.CS.Princeton.EDU^courses^archive^fa...
#
#                                                 text   class  \
# 0  Content-Type: text/html Content-Length: 1978 L...  course
# 1    CS 112: Data Structures   CS 112: Data Struc...  course
# 2  Set-Cookie: Apache=gs359343849035331353; path=...  course
# 3   CSE 110 (Accelerated) Home Page  CSE 110 (Acc...  course
# 4     COS 320: Compiling Techniques. Fall 1995   ...  course
#
#                                           keyphrase2  \
# 0  [(web operating, 0.6921), (web related, 0.535)...
# 1  [(programming unix, 0.6077), (programming assi...
# 2  [(event systems, 0.5776), (systems eecs, 0.524...
# ...

# %%
#df['class'] = df['file_name'].apply(lambda x: concerta(x))

# %%
df.head()
# Out:
#    id                                          file_name  \
# 0   0  http:^^www.cs.utexas.edu^users^dahlin^Classes^...
# 1   1   http:^^www.cs.rutgers.edu^~venugopa^112^112.html
# 2   2  http:^^www.eecs.umich.edu^courses^eecs661^eecs...
# 3   3     http:^^www.cis.upenn.edu^~cse110e^cse110e.html
# 4   4  http:^^www.CS.Princeton.EDU^courses^archive^fa...
#
#                                                 text   class  \
# 0  Content-Type: text/html Content-Length: 1978 L...  course
# 1    CS 112: Data Structures   CS 112: Data Struc...  course
# 2  Set-Cookie: Apache=gs359343849035331353; path=...  course
# 3   CSE 110 (Accelerated) Home Page  CSE 110 (Acc...  course
# 4     COS 320: Compiling Techniques. Fall 1995   ...  course
#
#                                           keyphrase2  \
# 0  [(web operating, 0.6921), (web related, 0.535)...
# 1  [(programming unix, 0.6077), (programming assi...
# 2  [(event systems, 0.5776), (systems eecs, 0.524...
# ...

# %%
classes = df["class"].unique()
print(sorted(classes))
class_number = len(classes)
print(class_number)
df["class"].value_counts().sort_values()
# Out:
# ['course', 'department', 'faculty', 'other', 'project', 'staff', 'student']
# 7
# class
# staff          137
# department     182
# project        504
# course         930
# faculty       1124
# student       1641
# other         3764
# Name: count, dtype: int64

# %%
# df.to_pickle('/content/drive/MyDrive/Mestrado_Grafos/processed_datasets/'+dataset_name+'/'+dataset_name+'.csv')
